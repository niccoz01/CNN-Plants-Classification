# %%
# Fix randomness and hide warnings
seed = 42

import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'
os.environ['PYTHONHASHSEED'] = str(seed)
os.environ['MPLCONFIGDIR'] = os.getcwd()+'/configs/'

import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)
warnings.simplefilter(action='ignore', category=Warning)

import numpy as np
np.random.seed(seed)

import logging

import random
random.seed(seed)

# %%
# Import tensorflow
import tensorflow as tf
from tensorflow import keras as tfk
from tensorflow.keras import layers as tfkl
from tensorflow.keras import initializers
tf.autograph.set_verbosity(0)
tf.get_logger().setLevel(logging.ERROR)
tf.compat.v1.logging.set_verbosity(tf.compat.v1.logging.ERROR)
tf.random.set_seed(seed)
tf.compat.v1.set_random_seed(seed)
print(tf.__version__)
# Out:
# 2.12.0

# %%
# Import other libraries
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, f1_score, precision_score, recall_score, confusion_matrix
from sklearn.utils import class_weight
import seaborn as sns

# %%
TRAIN_DIR="/kaggle/input/datadirectory/data/training_folder"
VAL_DIR="/kaggle/input/datadirectory/data/validation_folder"
TEST_DIR="/kaggle/input/datadirectory/data/test_folder"
IMG_SHAPE=(96,96)
BATCH_SIZE=32
NUM_CLASSES=2
INPUT_SHAPE = (*IMG_SHAPE,3)

# %%
import keras_tuner as kt
import time
from pathlib import Path

# %%
LOG_DIR = '/kaggle/working/kerastuner_logs'

import os
os.makedirs(LOG_DIR, exist_ok=True)

# %% [markdown]
# # **Data Generator**

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# train generator with augmentation
train_image_gen  = ImageDataGenerator(rotation_range=40,
                                      width_shift_range=0.2,
                                      height_shift_range=0.2,
                                      zoom_range=[0.5,1.5],
                                      brightness_range=[0.5,1.5],
                                      shear_range=0.2,
                                      vertical_flip=True,
                                      horizontal_flip=True,
                                      fill_mode='reflect',
                                      )

validation_image_gen = ImageDataGenerator()

train_dataset = train_image_gen.flow_from_directory(directory=TRAIN_DIR,
                                                    target_size=IMG_SHAPE,
                                                   # color_mode='rgb',
                                                    classes=None,
                                                    class_mode='binary',
                                                    batch_size=BATCH_SIZE,
                                                    shuffle=True,
                                                    seed=seed,
                                                    )

validation_dataset = validation_image_gen.flow_from_directory(directory=VAL_DIR,
                                                              target_size=IMG_SHAPE,
                                                             # color_mode='rgb',
                                                              classes=None,
                                                              class_mode='binary',
                                                              batch_size=BATCH_SIZE,
                                                              shuffle=False,
                                                              seed=seed,
                                                              )
# Out:
# Found 3928 images belonging to 2 classes.
# Found 437 images belonging to 2 classes.

# %%
class_weights = class_weight.compute_class_weight(class_weight='balanced',
                                                  classes=np.unique(train_dataset.classes),
                                                  y=train_dataset.classes)

class_weights = dict(zip(np.unique(train_dataset.classes), class_weights))
class_weights
# Out:
# {0: 0.7925746569814366, 1: 1.3544827586206896}

# %% [markdown]
# # **Tuning MobileNetV2**

# %%
conv_base  = tfk.applications.MobileNetV2(
    weights='imagenet',
    include_top=False,
    input_shape=(224, 224,3)
)
conv_base.trainable = False

# %%
def model_builder(hp):

    inputs = tfk.Input(shape=INPUT_SHAPE)

    x = tfkl.Resizing(224, 224, interpolation='bicubic')(inputs)
    x = tfk.applications.mobilenet.preprocess_input(x)
    x = conv_base(x)

    x = tfkl.GlobalAveragePooling2D()(x)
    
    # best activation
    hp_activation = hp.Choice('activation', values=['relu','tanh'])
    
    # best number of layers
    for i in range(hp.Int('n_layers',1,4)):
        # best number of neurons
        x = tfkl.Dense(units=hp.Int(f'units_{i}', min_value=128, max_value=512, step=128))(x)
        x = tfkl.BatchNormalization()(x)
        x = tfkl.Activation(hp_activation)(x)
        x = tfkl.Dropout(0.3)(x)


    outputs = tfkl.Dense(NUM_CLASSES, activation='softmax', kernel_initializer=tfk.initializers.GlorotUniform(seed=seed))(x)

    model = tfk.Model(inputs, outputs)
    
    # best lr
    # hp_learning_rate = hp.Choice('learning_rate',values=[1e-2,1e-3,1e-4])

    model.compile(loss=tfk.losses.SparseCategoricalCrossentropy(),
                  optimizer=tfk.optimizers.Adam(learning_rate=1e-3), metrics=['accuracy'])

    return model

# %%
tuner_mobilenet2 = kt.Hyperband(
    model_builder,
    objective='val_accuracy',
    max_epochs=10,
    directory=LOG_DIR,
    project_name='MobileNetV2')

tuner_mobilenet2.search(train_dataset,
             epochs=50,
             validation_data=validation_dataset,
             class_weight=class_weights,
             callbacks=[tfk.callbacks.EarlyStopping(monitor='val_loss', patience=5)])
# Out:
# Trial 30 Complete [00h 03m 19s]
# val_accuracy: 0.7711670398712158
#
# Best val_accuracy So Far: 0.8192219734191895
# Total elapsed time: 00h 41m 24s

# %%
tuner_mobilenet2.search_space_summary()
# Out:
# Search space summary
# Default search space size: 6
# activation (Choice)
# {'default': 'relu', 'conditions': [], 'values': ['relu', 'tanh'], 'ordered': False}
# n_layers (Int)
# {'default': None, 'conditions': [], 'min_value': 1, 'max_value': 4, 'step': 1, 'sampling': 'linear'}
# units_0 (Int)
# {'default': None, 'conditions': [], 'min_value': 128, 'max_value': 512, 'step': 128, 'sampling': 'linear'}
# units_1 (Int)
# {'default': None, 'conditions': [], 'min_value': 128, 'max_value': 512, 'step': 128, 'sampling': 'linear'}
# units_2 (Int)
# {'default': None, 'conditions': [], 'min_value': 128, 'max_value': 512, 'step': 128, 'sampling': 'linear'}
# units_3 (Int)
# {'default': None, 'conditions': [], 'min_value': 128, 'max_value': 512, 'step': 128, 'sampling': 'linear'}

# %%
best_hp = tuner_mobilenet2.get_best_hyperparameters()[0]
best_hp.values
# Out:
# {'activation': 'relu',
#  'n_layers': 1,
#  'units_0': 128,
#  'tuner/epochs': 10,
#  'tuner/initial_epoch': 4,
#  'tuner/bracket': 2,
#  'tuner/round': 2,
#  'tuner/trial_id': '0013',
#  'units_1': 512,
#  'units_2': 256,
#  'units_3': 256}

# %%
model = tuner_mobilenet2.hypermodel.build(best_hp)
model.summary()
# Out:
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 96, 96, 3)]       0
#
#  resizing_1 (Resizing)       (None, 224, 224, 3)       0
#
#  tf.math.truediv_1 (TFOpLamb  (None, 224, 224, 3)      0
#  da)
#
#  tf.math.subtract_1 (TFOpLam  (None, 224, 224, 3)      0
#  bda)
#
#  mobilenetv2_1.00_224 (Funct  (None, 7, 7, 1280)       2257984
#  ional)
#
#  global_average_pooling2d_1   (None, 1280)             0
#  (GlobalAveragePooling2D)
#
#  dense_5 (Dense)             (None, 128)               163968
#
#  batch_normalization_4 (Batc  (None, 128)              512
#  hNormalization)
#
#  activation_4 (Activation)   (None, 128)               0
#
#  dropout_4 (Dropout)         (None, 128)               0
#
#  dense_6 (Dense)             (None, 2)                 258
#
# =================================================================
# Total params: 2,422,722
# Trainable params: 164,482
# Non-trainable params: 2,258,240
# _________________________________________________________________

# %%
stop_early = tfk.callbacks.EarlyStopping(monitor='val_accuracy', mode='max', patience=15, restore_best_weights=True)
plateau = tfk.callbacks.ReduceLROnPlateau(monitor='val_accuracy',patience=5,factor=0.85,mode='auto',min_lr=1e-5)

# Train the model
history = model.fit(
    train_dataset, # We need to apply the preprocessing thought for the MobileNetV2 network
    batch_size = 64,
    epochs = 120,
    validation_data = validation_dataset, # We need to apply the preprocessing thought for the MobileNetV2 network
    class_weight=class_weights,
    callbacks = [stop_early, plateau]
).history
# Out:
# Epoch 1/120
# 123/123 [==============================] - 31s 221ms/step - loss: 0.7169 - accuracy: 0.6622 - val_loss: 0.5732 - val_accuracy: 0.7391 - lr: 0.0010
# Epoch 2/120
# 123/123 [==============================] - 21s 169ms/step - loss: 0.5870 - accuracy: 0.7070 - val_loss: 0.4844 - val_accuracy: 0.7803 - lr: 0.0010
# Epoch 3/120
# 123/123 [==============================] - 19s 154ms/step - loss: 0.5625 - accuracy: 0.7207 - val_loss: 0.4949 - val_accuracy: 0.7666 - lr: 0.0010
# Epoch 4/120
# 123/123 [==============================] - 19s 156ms/step - loss: 0.5486 - accuracy: 0.7138 - val_loss: 0.4511 - val_accuracy: 0.7963 - lr: 0.0010
# Epoch 5/120
# 123/123 [==============================] - 19s 154ms/step - loss: 0.5148 - accuracy: 0.7406 - val_loss: 0.4510 - val_accuracy: 0.7918 - lr: 0.0010
# Epoch 6/120
# 123/123 [==============================] - 19s 153ms/step - loss: 0.5223 - accuracy: 0.7296 - val_loss: 0.4391 - val_accuracy: 0.7826 - lr: 0.0010
# Epoch 7/120
# 123/123 [==============================] - 19s 152ms/step - loss: 0.5099 - accuracy: 0.7464 - val_loss: 0.4701 - val_accuracy: 0.7849 - lr: 0.0010
# Epoch 8/120
# 123/123 [==============================] - 19s 158ms/step - loss: 0.5037 - accuracy: 0.7467 - val_loss: 0.4263 - val_accuracy: 0.7941 - lr: 0.0010
# Epoch 9/120
# 123/123 [==============================] - 19s 154ms/step - loss: 0.4902 - accuracy: 0.7553 - val_loss: 0.4686 - val_accuracy: 0.7826 - lr: 0.0010
# Epoch 10/120
# 123/123 [==============================] - 19s 156ms/step - loss: 0.4947 - accuracy: 0.7587 - val_loss: 0.4471 - val_accuracy: 0.7826 - lr: 8.5000e-04
# Epoch 11/120
# 123/123 [==============================] - 19s 152ms/step - loss: 0.4852 - accuracy: 0.7665 - val_loss: 0.4546 - val_accuracy: 0.7872 - lr: 8.5000e-04
# Epoch 12/120
# 123/123 [==============================] - 18s 150ms/step - loss: 0.4933 - accuracy: 0.7584 - val_loss: 0.4674 - val_accuracy: 0.7666 - lr: 8.5000e-04
# Epoch 13/120
# 123/123 [==============================] - 18s 149ms/step - loss: 0.4874 - accuracy: 0.7599 - val_loss: 0.4643 - val_accuracy: 0.7803 - lr: 8.5000e-04
# Epoch 14/120
# 123/123 [==============================] - 19s 152ms/step - loss: 0.4781 - accuracy: 0.7671 - val_loss: 0.4513 - val_accuracy: 0.7895 - lr: 8.5000e-04
# Epoch 15/120
# 123/123 [==============================] - 19s 152ms/step - loss: 0.4876 - accuracy: 0.7609 - val_loss: 0.4567 - val_accuracy: 0.7986 - lr: 7.2250e-04
# Epoch 16/120
# 123/123 [==============================] - 19s 152ms/step - loss: 0.4714 - accuracy: 0.7686 - val_loss: 0.4656 - val_accuracy: 0.7803 - lr: 7.2250e-04
# Epoch 17/120
# 123/123 [==============================] - 19s 158ms/step - loss: 0.4800 - accuracy: 0.7630 - val_loss: 0.4394 - val_accuracy: 0.8032 - lr: 7.2250e-04
# Epoch 18/120
# 123/123 [==============================] - 18s 149ms/step - loss: 0.4743 - accuracy: 0.7673 - val_loss: 0.4481 - val_accuracy: 0.7986 - lr: 7.2250e-04
# Epoch 19/120
# 123/123 [==============================] - 18s 149ms/step - loss: 0.4702 - accuracy: 0.7765 - val_loss: 0.4379 - val_accuracy: 0.7963 - lr: 7.2250e-04
# Epoch 20/120
# 123/123 [==============================] - 19s 155ms/step - loss: 0.4635 - accuracy: 0.7752 - val_loss: 0.4834 - val_accuracy: 0.7735 - lr: 7.2250e-04
# Epoch 21/120
# 123/123 [==============================] - 19s 151ms/step - loss: 0.4715 - accuracy: 0.7701 - val_loss: 0.4447 - val_accuracy: 0.7918 - lr: 7.2250e-04
# Epoch 22/120
# 123/123 [==============================] - 18s 150ms/step - loss: 0.4742 - accuracy: 0.7762 - val_loss: 0.4442 - val_accuracy: 0.7963 - lr: 7.2250e-04
# Epoch 23/120
# 123/123 [==============================] - 18s 148ms/step - loss: 0.4687 - accuracy: 0.7747 - val_loss: 0.4420 - val_accuracy: 0.7895 - lr: 6.1413e-04
# Epoch 24/120
# 123/123 [==============================] - 19s 151ms/step - loss: 0.4609 - accuracy: 0.7788 - val_loss: 0.4450 - val_accuracy: 0.7986 - lr: 6.1413e-04
# Epoch 25/120
# 123/123 [==============================] - 19s 151ms/step - loss: 0.4672 - accuracy: 0.7711 - val_loss: 0.4795 - val_accuracy: 0.7826 - lr: 6.1413e-04
# Epoch 26/120
# 123/123 [==============================] - 18s 150ms/step - loss: 0.4638 - accuracy: 0.7742 - val_loss: 0.4325 - val_accuracy: 0.8032 - lr: 6.1413e-04
# Epoch 27/120
# 123/123 [==============================] - 19s 151ms/step - loss: 0.4619 - accuracy: 0.7772 - val_loss: 0.4596 - val_accuracy: 0.7918 - lr: 6.1413e-04
# Epoch 28/120
# 123/123 [==============================] - 18s 149ms/step - loss: 0.4693 - accuracy: 0.7752 - val_loss: 0.4331 - val_accuracy: 0.8009 - lr: 5.2201e-04
# Epoch 29/120
# 123/123 [==============================] - 18s 150ms/step - loss: 0.4516 - accuracy: 0.7869 - val_loss: 0.4367 - val_accuracy: 0.8009 - lr: 5.2201e-04
# Epoch 30/120
# 123/123 [==============================] - 19s 154ms/step - loss: 0.4651 - accuracy: 0.7719 - val_loss: 0.4320 - val_accuracy: 0.8078 - lr: 5.2201e-04
# Epoch 31/120
# 123/123 [==============================] - 18s 150ms/step - loss: 0.4594 - accuracy: 0.7867 - val_loss: 0.4429 - val_accuracy: 0.7941 - lr: 5.2201e-04
# Epoch 32/120
# 123/123 [==============================] - 19s 151ms/step - loss: 0.4690 - accuracy: 0.7686 - val_loss: 0.4290 - val_accuracy: 0.7963 - lr: 5.2201e-04
# Epoch 33/120
# 123/123 [==============================] - 19s 153ms/step - loss: 0.4610 - accuracy: 0.7732 - val_loss: 0.4244 - val_accuracy: 0.8032 - lr: 5.2201e-04
# Epoch 34/120
# 123/123 [==============================] - 19s 155ms/step - loss: 0.4533 - accuracy: 0.7849 - val_loss: 0.4341 - val_accuracy: 0.8078 - lr: 5.2201e-04
# Epoch 35/120
# 123/123 [==============================] - 19s 152ms/step - loss: 0.4593 - accuracy: 0.7800 - val_loss: 0.4257 - val_accuracy: 0.8078 - lr: 5.2201e-04
# Epoch 36/120
# 123/123 [==============================] - 19s 153ms/step - loss: 0.4661 - accuracy: 0.7811 - val_loss: 0.4282 - val_accuracy: 0.8009 - lr: 4.4371e-04
# Epoch 37/120
# 123/123 [==============================] - 19s 153ms/step - loss: 0.4438 - accuracy: 0.7808 - val_loss: 0.4321 - val_accuracy: 0.8078 - lr: 4.4371e-04
# Epoch 38/120
# 123/123 [==============================] - 19s 151ms/step - loss: 0.4237 - accuracy: 0.8045 - val_loss: 0.4265 - val_accuracy: 0.7941 - lr: 4.4371e-04
# Epoch 39/120
# 123/123 [==============================] - 19s 154ms/step - loss: 0.4450 - accuracy: 0.7928 - val_loss: 0.4240 - val_accuracy: 0.8032 - lr: 4.4371e-04
# Epoch 40/120
# 123/123 [==============================] - 19s 154ms/step - loss: 0.4411 - accuracy: 0.7836 - val_loss: 0.4215 - val_accuracy: 0.8055 - lr: 4.4371e-04
# Epoch 41/120
# 123/123 [==============================] - 18s 148ms/step - loss: 0.4486 - accuracy: 0.7884 - val_loss: 0.4342 - val_accuracy: 0.7941 - lr: 3.7715e-04
# Epoch 42/120
# 123/123 [==============================] - 19s 155ms/step - loss: 0.4439 - accuracy: 0.7900 - val_loss: 0.4211 - val_accuracy: 0.8078 - lr: 3.7715e-04
# Epoch 43/120
# 123/123 [==============================] - 19s 151ms/step - loss: 0.4496 - accuracy: 0.7864 - val_loss: 0.4172 - val_accuracy: 0.8169 - lr: 3.7715e-04
# Epoch 44/120
# 123/123 [==============================] - 19s 152ms/step - loss: 0.4461 - accuracy: 0.7826 - val_loss: 0.4244 - val_accuracy: 0.8055 - lr: 3.7715e-04
# Epoch 45/120
# 123/123 [==============================] - 19s 153ms/step - loss: 0.4498 - accuracy: 0.7777 - val_loss: 0.4308 - val_accuracy: 0.7963 - lr: 3.7715e-04
# Epoch 46/120
# 123/123 [==============================] - 19s 151ms/step - loss: 0.4273 - accuracy: 0.8073 - val_loss: 0.4191 - val_accuracy: 0.8032 - lr: 3.7715e-04
# Epoch 47/120
# 123/123 [==============================] - 19s 150ms/step - loss: 0.4409 - accuracy: 0.7867 - val_loss: 0.4115 - val_accuracy: 0.8124 - lr: 3.7715e-04
# Epoch 48/120
# 123/123 [==============================] - 19s 153ms/step - loss: 0.4556 - accuracy: 0.7793 - val_loss: 0.4279 - val_accuracy: 0.7986 - lr: 3.7715e-04
# Epoch 49/120
# 123/123 [==============================] - 19s 151ms/step - loss: 0.4344 - accuracy: 0.7915 - val_loss: 0.4287 - val_accuracy: 0.8078 - lr: 3.2058e-04
# Epoch 50/120
# 123/123 [==============================] - 19s 151ms/step - loss: 0.4336 - accuracy: 0.7923 - val_loss: 0.4221 - val_accuracy: 0.8009 - lr: 3.2058e-04
# Epoch 51/120
# 123/123 [==============================] - 18s 146ms/step - loss: 0.4543 - accuracy: 0.7826 - val_loss: 0.4412 - val_accuracy: 0.8032 - lr: 3.2058e-04
# Epoch 52/120
# 123/123 [==============================] - 18s 149ms/step - loss: 0.4331 - accuracy: 0.7935 - val_loss: 0.4252 - val_accuracy: 0.8169 - lr: 3.2058e-04
# Epoch 53/120
# 123/123 [==============================] - 19s 151ms/step - loss: 0.4298 - accuracy: 0.7938 - val_loss: 0.4448 - val_accuracy: 0.7986 - lr: 3.2058e-04
# Epoch 54/120
# 123/123 [==============================] - 19s 153ms/step - loss: 0.4328 - accuracy: 0.8014 - val_loss: 0.4295 - val_accuracy: 0.8101 - lr: 2.7249e-04
# Epoch 55/120
# 123/123 [==============================] - 19s 151ms/step - loss: 0.4353 - accuracy: 0.7920 - val_loss: 0.4263 - val_accuracy: 0.8032 - lr: 2.7249e-04
# Epoch 56/120
# 123/123 [==============================] - 19s 152ms/step - loss: 0.4318 - accuracy: 0.7943 - val_loss: 0.4258 - val_accuracy: 0.8169 - lr: 2.7249e-04
# Epoch 57/120
# 123/123 [==============================] - 19s 152ms/step - loss: 0.4260 - accuracy: 0.8065 - val_loss: 0.4255 - val_accuracy: 0.8124 - lr: 2.7249e-04
# Epoch 58/120
# 123/123 [==============================] - 19s 152ms/step - loss: 0.4433 - accuracy: 0.7943 - val_loss: 0.4307 - val_accuracy: 0.8032 - lr: 2.7249e-04
